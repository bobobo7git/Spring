# %% [markdown]
# # REST API

# %% [markdown]
# ### REST
# > Representational State Transfer
# > HTTP 프로토콜을 사용하여 데이터를 주고받는 방법
# > `HTTP URI`를 통해 제어할 자원을 명시하고, `HTTP Method`를 통해 해당 자원을 제어하는 명령을 내리는 방식의 아키텍처
#
# ### API
# > Application Programming Interface
# > 다른 소프트웨어 애플리케이션에서 사용할 수 있는 기능을 제공하는 인터페이스
#
# ![image.png](attachment:image.png)
